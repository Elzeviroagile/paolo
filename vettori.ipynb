# %% [markdown]
# <a href="https://colab.research.google.com/github/Elzeviroagile/paolo/blob/main/vettori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
myVect = np.array([1, 2, 3, 4])
# Out:
# ('myVect', '=', 'np.array([1,', '2,', '3,', '4])')

# %%
myVect = np.arange(1, 10, 2)
myVect = [1, 3, 5, 7, 9]
myVect = np.int16([1, 2, 3, 4])
print(type(myVect[0]))
myVect + 1 
a = np.array([1, 2, 3, 4])
b = np.array([2, 2, 4, 4])
 
print(a == b)
print(a < b)
a = np.array([True, False, True, False])
b = np.array([True, True, False, False])
 
print(np.logical_or(a, b))
print(np.logical_and(a, b))
print(np.logical_not(a))
print(np.logical_xor(a, b) )

myVect * myVect
np.multiply(myVect, myVect)
# Out:
# <class 'numpy.int16'>
# [False  True False  True]
# [ True False  True False]
# [ True  True  True False]
# [ True False False False]
# [False  True False  True]
# [False  True  True False]
# array([ 1,  4,  9, 16], dtype=int16)

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
